# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

Dataset = pd.read_csv('Social_Network_Ads.csv')

# %%
Dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
X = Dataset.iloc[:,[2,3]].values
y = Dataset.iloc[:,-1].values

# filter out the applicants that got admitted
purchased = Dataset.loc[y==1]
#filter out the applicants that were not admitted
not_purchased = Dataset.loc[y==0]

purchased
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 7    15694829  Female   32           150000          1
# 16   15733883    Male   47            25000          1
# 17   15617482    Male   45            26000          1
# 18   15704583    Male   46            28000          1
# 19   15621083  Female   48            29000          1
# ..        ...     ...  ...              ...        ...
# 393  15635893    Male   60            42000          1
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 399  15594041  Female   49            36000          1
#
# [143 rows x 5 columns]

# %%
not_purchased
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 377  15800215  Female   42            53000          0
# 380  15683758    Male   42            64000          0
# 387  15627220    Male   39            71000          0
# 394  15757632  Female   39            59000          0
# 398  15755018    Male   36            33000          0
#
# [257 rows x 5 columns]

# %%
plt.scatter(purchased.iloc[:,2],purchased.iloc[:,3],s=10,label = 'admitted')
plt.title = 'admitted'
plt.show()

# %%
plt.scatter(not_purchased.iloc[:,0],not_purchased.iloc[:,3],s=10 ,label = 'not_admitted')

# %%
X = np.c_[np.ones((X.shape[0],1)),X]
y = y[:,np.newaxis]
theta = np.zeros((X.shape[1],1))
